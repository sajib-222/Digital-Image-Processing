# %% [markdown]
# <a href="https://colab.research.google.com/github/sajib-222/Digital-Image-Processing/blob/main/image_handaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request
import cv2
from PIL import Image

# %%
image_path = '/content/drive/MyDrive/Digital Image Process/image/piza(2).jpg'

# %%
img = cv2.imread(image_path)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.axis('off')
plt.title
plt.show()

# %%
# Step 1: Provide the URL of the image
image_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0CiIHk2GvUnccbPnNETY6wt5cGtj9NsIV2A&s'  # Replace with the actual URL

# %%
# Step 2: Download the image using urllib
with urllib.request.urlopen(image_url) as response:
    img_array = np.asarray(bytearray(response.read()), dtype=np.uint8)  # Convert to NumPy array

# %%
# Step 3: Decode the image (convert it into OpenCV format)
img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)  # Decode as a color image (BGR format)

# %%
# Step 4: Convert BGR to RGB for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Step 5: Display the image using Matplotlib
plt.imshow(img_rgb)
plt.axis('off')  # Remove axes for cleaner display
plt.title("Image from URL")
plt.show()

# %% [markdown]
# ## 1. a)	Display the properties of the given image like height, width, no. of channels and size.

# %%
# Step 1: Get the image properties
height, width, channels = img.shape  # Height, width, and number of color channels
size = img.size  # Total number of pixels (width × height × channels)

# %%
# Step 2: Print the properties
print("Image Properties:")
print(f"Height: {height} pixels")
print(f"Width: {width} pixels")
print(f"Number of Channels: {channels}")
print(f"Size: {size} bytes")  # Total size in bytes
# Out:
# Image Properties:
# Height: 251 pixels
# Width: 201 pixels
# Number of Channels: 3
# Size: 151353 bytes

# %% [markdown]
# ## 1. b)	Display the individual channels (R, G, B) pixel values in that image.

# %%
# Step 1: Split the image into its B, G, R channels
blue_channel, green_channel, red_channel = cv2.split(img)

# %%
# Step 2: Display the pixel values of each channel
print("Blue Channel Pixel Values:")
print(blue_channel)

print("\nGreen Channel Pixel Values:")
print(green_channel)

print("\nRed Channel Pixel Values:")
print(red_channel)
# Out:
# Blue Channel Pixel Values:
# [[  0   0   2 ...   0   0   0]
#  [  0   4  11 ...  35  36   8]
#  [  7  13  16 ... 101 114  85]
#  ...
#  [ 10  12  15 ...  63  60  60]
#  [ 10  12  15 ...  63  60  60]
#  [ 10  12  15 ...  63  60  59]]
#
# Green Channel Pixel Values:
# [[ 4  3  4 ...  0  0  0]
#  [ 7  8 11 ...  8  6  0]
#  [ 6 10 11 ... 57 61 25]
#  ...
#  [ 3  5  8 ... 44 43 39]
#  [ 3  5  8 ... 44 43 40]
#  [ 3  5  8 ... 44 43 39]]
#
# Red Channel Pixel Values:
# [[  0   0   0 ...  71  79  57]
#  [  0   2   5 ...  72  81  70]
#  [  2   6   8 ...  94 100  73]
#  ...
#  [  0   2   5 ...  17  16  17]
#  [  0   2   5 ...  17  16  15]
#  [  0   2   5 ...  17  16  14]]

# %% [markdown]
# ## 1.c) Separate the given color image in three R G & B color channels.

# %%
# Step 1: Visualize the individual channels
# Convert each channel to grayscale for display
plt.figure(figsize=(10, 8))

plt.subplot(1, 3, 1)
plt.title("Blue Channel")
plt.imshow(blue_channel,cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title("Green Channel")
plt.imshow(green_channel,cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title("Red Channel")
plt.imshow(red_channel,cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.d) Convert the given color image into gray-scale image and display the shape of the gray-scale image.

# %%
# Step 1: Convert the image to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 2: Display the shape of the grayscale image
print(f"Shape of the Grayscale Image: {gray_image.shape}")

# Step 3: Visualize the grayscale image
plt.figure(figsize=(6, 6))
plt.title("Grayscale Image")
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Shape of the Grayscale Image: (251, 201)

# %% [markdown]
# # Crop the image

# %%
img_crop=img_rgb[0:200,0:300]
plt.imshow(img_crop)
plt.axis('off')
plt.title('croped image')
plt.show()
